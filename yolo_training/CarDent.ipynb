# %%
# !nvidia-smi
# Out:
# Sat Apr 25 10:59:56 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             14W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Installing Ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Mounting Google Drive with Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Training the YOLOv8l Model

# %%
#epochs=100 best for the dataset and model sizes
#patience=20 utomatically stops training early if the model stops improving, saving Colab GPU time.

# !yolo task=detect mode=train model=yolov8l.pt data=/content/drive/MyDrive/Datasetsv1/CarDent/data.yaml epochs=100 imgsz=640 patience=20
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# ### Evaluation

# %%
from ultralytics import YOLO

model = YOLO("best.pt")
metrics = model.val(data="/content/drive/MyDrive/Datasetsv1/CarDent/data.yaml")

print("mAP50:    ", metrics.box.map50)
print("mAP50-95: ", metrics.box.map)
print("Precision:", metrics.box.mp)
print("Recall:   ", metrics.box.mr)
# Out:
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 113 layers, 43,615,860 parameters, 0 gradients, 164.9 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.6±0.1 ms, read: 0.1±0.1 MB/s, size: 19.4 KB)
# val: Scanning /content/drive/MyDrive/Datasetsv1/CarDent/valid/labels.cache... 678 images, 22 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 678/678 86.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 1.4it/s 30.0s
#                    all        678        987       0.55      0.515      0.505      0.231
# Front-Windscreen-Damage         32         33      0.522      0.545      0.438      0.253
#       Headlight-Damage         64         68      0.539      0.345      0.398      0.179
# Rear-windscreen-Damage         50         51      0.617      0.784      0.752      0.396
#      Sidemirror-Damage         26         26       0.68      0.735      0.759      0.437
# ...
